# %% [markdown]
# <a href="https://colab.research.google.com/github/gourikhan/project/blob/master/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #it is a method to extract data from a website that doesnot have an API

# %%
#import urllib2
import urllib

# %%
import urllib.request

# %%
#define link for extracting information:
wiki = "https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"

# %%
page = urllib.request.urlopen(wiki)

# %%
#import sys
#print(sys.version)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page)

# %%
#page = urllib.request.urlopen(wiki)
#soup = BeautifulSoup(page)

# %%
soup.title
# Out:
# <title>List of state and union territory capitals in India - Wikipedia</title>

# %%
soup.title.string
# Out:
# 'List of state and union territory capitals in India - Wikipedia'

# %%
soup.a #a is for hyperlink
# Out:
# <a id="top"></a>

# %%
all_tables=soup.find_all('table')
#all_tables

# %%
#right_table = soup.find("table",{"class" : "wikitable sortable" }) #"class" : "wikitable sortable" 
#right_table #States and Union Territories #"class_": "wikitable sortable plainrowheaders"

# %%
res = requests.get("https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India")
soup = BeautifulSoup(res.content, "html.parser")
tables = soup.find_all("table", class_="wikitable sortable")
print(len(tables))
# Out:
# 0

# %%
r = requests.get("https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India")
x = BeautifulSoup(r.content)
x.find_all("table",{"class":"wikitable sortable jquery-tablesorter"})
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India")                                                  
soup = BeautifulSoup(res.text, 'lxml') #if you find any problem with "lxml" then try using "html.parser" instead
table = soup.find("table",class_="wikitable")
for items in table.find_all("tr")[:-1]:
    data = [' '.join(item.text.split()) for item in items.find_all(['th','td'])]
    print(data)
# Out:
# ['No.', 'State orunion territory', 'Administrative capital', 'Legislative capital', 'Judicial capital', 'Year of establishment', 'Former capital']
# ['1', 'Andaman and Nicobar Islands', '[[Port Blair ]]', '—', 'Kolkata', '1956', '—']
# ['2', 'Andhra Pradesh', 'Hyderabad(de facto from 2017)[3][4][a]', 'Amaravati[3]', 'Amaravati', '19562014', 'Hyderabad[b](1956–2017)']
# ['3', 'Arunachal Pradesh', 'Itanagar', 'Itanagar', 'Guwahati', '1987', '—']
# ['4', 'Assam', 'Dispur', 'Guwahati', 'Guwahati', '1972', 'Shillong[c] (1950–1972)']
# ['5', 'Bihar', 'Patna', 'Patna', 'Patna', '1950', '—']
# ['6', 'Chandigarh', 'Chandigarh[d]', '—', 'Chandigarh', '1966', '—']
# ['7', 'Chhattisgarh', 'Naya Raipur', 'Raipur', 'Bilaspur', '2000', '—']
# ['8', 'Dadra and Nagar Haveli and Daman and Diu', 'Daman', '—', 'Mumbai', '2020', '—']
# ['9', 'Delhi', 'New Delhi', 'New Delhi', 'New Delhi', '1956', '—']
# ['10', 'Goa', 'Panaji[e]', 'Porvorim', 'Mumbai', '1987', '—']
# ...

# %%
#right = soup.find("table",class_="wikitable")
#("table",class_="wikitable") #('table', class_='wikitable sortable plainrowheaders')

# %%
right_tables = soup.find('table',{'class':'wikitable sortable plainrowheaders'})

# %%
right_tables
# Out:
# <table class="wikitable sortable plainrowheaders">
# <tbody><tr>
# <th scope="col">No.
# </th>
# <th scope="col">State or<br/>union territory
# </th>
# <th scope="col">Administrative capital
# </th>
# <th scope="col">Legislative capital
# </th>
# <th scope="col">Judicial capital
# </th>
# <th scope="col">Year of establishment
# </th>
# <th scope="col">Former capital
# </th></tr>
# <tr>
# <td>1
# </td>
# <th scope="row"><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a> <img alt="union territory" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </th>
# <td>[[Port Blair
# <p>]]
# </p>
# </td>
# <td> —
# </td>
# <td><a href="/wiki/Kolkata" title="Kolkata">Kolkata</a>
# </td>
# <td>1956
# </td>
# <td> —
# </td></tr>
# <tr>
# <td>2
# </td>
# ...

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]

# %%
for row in right_tables.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') #To store second column data
    if len(cells)==6: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(cells[3].find(text=True))
        F.append(cells[4].find(text=True))
        G.append(cells[5].find(text=True))

# %%
import pandas as pd

# %%
df=pd.DataFrame(A,columns=['Number'])
df['State/UT']=B
df['Admin_Capital']=C
df['Legislative_Capital']=D
df['Judiciary_Capital']=E
df['Year_Capital']=F
df['Former_Capital']=G
df
# Out:
#    Number  ...           Former_Capital
# 0     1\n  ...                      —\n
# 1     2\n  ...                Hyderabad
# 2     3\n  ...                      —\n
# 3     4\n  ...                 Shillong
# 4     5\n  ...                      —\n
# 5     6\n  ...                      —\n
# 6     7\n  ...                      —\n
# 7     8\n  ...                      —\n
# 8     9\n  ...                      —\n
# 9    10\n  ...                      —\n
# 10   11\n  ...  Ahmedabad (1960–1970)\n
# 11   12\n  ...                      —\n
# 12   13\n  ...                      —\n
# 13   14\n  ...                      —\n
# 14   15\n  ...                      —\n
# 15   16\n  ...                      —\n
# 16   17\n  ...                      —\n
# 17   18\n  ...                      —\n
# 18   19\n  ...                      —\n
# 19   20\n  ...                      —\n
# 20   21\n  ...                      —\n
# 21   22\n  ...                      —\n
# ...

# %%
df = df.replace ('\n' , '',regex = True)

# %%
#all_tables
